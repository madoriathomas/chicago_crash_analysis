# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('data/Traffic_Crashes_-_Crashes.csv')
df.head()
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  0056da66abbbe3801471a3b091e81b7a7a647d8b5370ca...  JF146223
# 1  00b7a4e1b4ec9acc282a6125c2b5e1392cbdb7aea76d4e...  JF145979
# 2  00be1ed4070e88be42fd908be7bb870891b7c6a1f19c0f...  JF146627
# 3  016adff891fac9cf8c00533dc3155e5ff989723091ce47...  JF155027
# 4  01372009fc45a88352b86e3438fe440f97980e91ae0797...  JF151203
#
#   CRASH_DATE_EST_I              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0              NaN  02/16/2022 11:30:00 AM                  15
# 1              NaN  02/16/2022 08:24:00 AM                  30
# 2              NaN  02/16/2022 05:14:00 PM                  30
# 3              NaN  02/24/2022 06:01:00 PM                  30
# 4              NaN  02/21/2022 09:29:00 AM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0            NO CONTROLS           NO CONTROLS             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594270 entries, 0 to 594269
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                594270 non-null  object
#  1   RD_NO                          590432 non-null  object
#  2   CRASH_DATE_EST_I               44905 non-null   object
#  3   CRASH_DATE                     594270 non-null  object
#  4   POSTED_SPEED_LIMIT             594270 non-null  int64
#  5   TRAFFIC_CONTROL_DEVICE         594270 non-null  object
#  6   DEVICE_CONDITION               594270 non-null  object
#  7   WEATHER_CONDITION              594270 non-null  object
#  8   LIGHTING_CONDITION             594270 non-null  object
#  9   FIRST_CRASH_TYPE               594270 non-null  object
#  10  TRAFFICWAY_TYPE                594270 non-null  object
#  11  LANE_CNT                       198981 non-null  float64
# ...

# %%
to_drop = ['CRASH_RECORD_ID', 'CRASH_DATE_EST_I', 'LANE_CNT', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'PHOTOS_TAKEN_I',\
    'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'LOCATION']

new_df = df.drop(to_drop, axis=1)
new_df.head()
# Out:
#       RD_NO              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0  JF146223  02/16/2022 11:30:00 AM                  15
# 1  JF145979  02/16/2022 08:24:00 AM                  30
# 2  JF146627  02/16/2022 05:14:00 PM                  30
# 3  JF155027  02/24/2022 06:01:00 PM                  30
# 4  JF151203  02/21/2022 09:29:00 AM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0            NO CONTROLS           NO CONTROLS             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2                  OTHER                 OTHER              RAIN
# 3            NO CONTROLS           NO CONTROLS              SNOW
# 4      STOP SIGN/FLASHER  FUNCTIONING PROPERLY    FOG/SMOKE/HAZE
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE  \
# 0                DAYLIGHT              REAR TO REAR
# 1                DAYLIGHT  SIDESWIPE SAME DIRECTION
# 2  DARKNESS, LIGHTED ROAD                   TURNING
# ...

# %%
new_df['MOST_SEVERE_INJURY'].value_counts()
# Out:
# NO INDICATION OF INJURY     514364
# NONINCAPACITATING INJURY     44098
# REPORTED, NOT EVIDENT        24011
# INCAPACITATING INJURY         9926
# FATAL                          628
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
new_df['PRIM_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# UNABLE TO DETERMINE                                                                 224267
# FAILING TO YIELD RIGHT-OF-WAY                                                        64815
# FOLLOWING TOO CLOSELY                                                                60673
# NOT APPLICABLE                                                                       31693
# IMPROPER OVERTAKING/PASSING                                                          28316
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               25763
# IMPROPER BACKING                                                                     25013
# IMPROPER LANE USAGE                                                                  22341
# IMPROPER TURNING/NO SIGNAL                                                           19619
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  18868
# ...

# %%
new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace(['DISTRACTION - FROM INSIDE VEHICLE',
     'DISTRACTION - FROM OUTSIDE VEHICLE', 'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)', 
     'CELL PHONE USE OTHER THAN TEXTING', 'TEXTING'], 'DISTRACTION/CELL PHONE USE')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace(['DISREGARDING STOP SIGN',
      'DISREGARDING OTHER TRAFFIC SIGNS', 'DISREGARDING ROAD MARKINGS', 'DISREGARDING YIELD SIGN', 
      'BICYCLE ADVANCING LEGALLY ON RED LIGHT', 'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT'], 'DISREGARDING TRAFFIC SIGNALS')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace(['DRIVING ON WRONG SIDE/WRONG WAY',
     'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER', 'FOLLOWING TOO CLOSELY',
     'IMPROPER OVERTAKING/PASSING', 'IMPROPER BACKING', 'IMPROPER LANE USAGE', 'IMPROPER TURNING/NO SIGNAL', 'PASSING STOPPED SCHOOL BUS',
     'TURNING RIGHT ON RED', 'RELATED TO BUS STOP'], 'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace('NOT APPLICABLE', 'UNABLE TO DETERMINE')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace(['EXCEEDING AUTHORIZED SPEED LIMIT',
     'EXCEEDING SAFE SPEED FOR CONDITIONS', 'FAILING TO REDUCE SPEED TO AVOID CRASH'], 'SPEEDING')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace('ANIMAL', 'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace(['UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
      'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)'], 'UNDER THE INFLUENCE')

new_df['PRIM_CONTRIBUTORY_CAUSE'] = new_df['PRIM_CONTRIBUTORY_CAUSE'].replace(['ROAD ENGINEERING/SURFACE/MARKING DEFECTS', 
      'OBSTRUCTED CROSSWALKS'], 'ROAD CONSTRUCTION/MAINTENANCE')

# %%
new_df['SEC_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# NOT APPLICABLE                                                                      241658
# UNABLE TO DETERMINE                                                                 213875
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               23945
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  18383
# FAILING TO YIELD RIGHT-OF-WAY                                                        17961
# FOLLOWING TOO CLOSELY                                                                15869
# IMPROPER OVERTAKING/PASSING                                                           8760
# IMPROPER LANE USAGE                                                                   8477
# WEATHER                                                                               7404
# IMPROPER TURNING/NO SIGNAL                                                            5895
# ...

# %%
new_df['FIRST_CRASH_TYPE'].value_counts()
# Out:
# PARKED MOTOR VEHICLE            138439
# REAR END                        137878
# SIDESWIPE SAME DIRECTION         90367
# TURNING                          83421
# ANGLE                            63863
# FIXED OBJECT                     27968
# PEDESTRIAN                       13584
# SIDESWIPE OPPOSITE DIRECTION      8639
# PEDALCYCLIST                      8537
# OTHER OBJECT                      5759
# HEAD ON                           5134
# REAR TO FRONT                     4415
# REAR TO SIDE                      2607
# OTHER NONCOLLISION                1900
# REAR TO REAR                       954
# ANIMAL                             407
# OVERTURNED                         362
# TRAIN                               36
# Name: FIRST_CRASH_TYPE, dtype: int64

# %%
new_df['CRASH_TYPE'].value_counts()
# Out:
# NO INJURY / DRIVE AWAY              440888
# INJURY AND / OR TOW DUE TO CRASH    153382
# Name: CRASH_TYPE, dtype: int64

# %%
new_df['NUM_UNITS'].value_counts()
# Out:
# 2     520500
# 1      32669
# 3      32631
# 4       6271
# 5       1484
# 6        443
# 7        156
# 8         61
# 9         29
# 10        12
# 11         6
# 12         3
# 14         2
# 15         1
# 18         1
# 16         1
# Name: NUM_UNITS, dtype: int64

# %%
new_df['REPORT_TYPE'].value_counts()
# Out:
# NOT ON SCENE (DESK REPORT)    331828
# ON SCENE                      246992
# AMENDED                          240
# Name: REPORT_TYPE, dtype: int64

# %%
new_df['TRAFFIC_CONTROL_DEVICE'].value_counts()
# Out:
# NO CONTROLS                 341702
# TRAFFIC SIGNAL              165057
# STOP SIGN/FLASHER            59178
# UNKNOWN                      19699
# OTHER                         3665
# LANE USE MARKING              1226
# YIELD                          830
# OTHER REG. SIGN                615
# OTHER WARNING SIGN             532
# RAILROAD CROSSING GATE         397
# PEDESTRIAN CROSSING SIGN       297
# POLICE/FLAGMAN                 209
# SCHOOL ZONE                    208
# DELINEATORS                    207
# FLASHING CONTROL SIGNAL        192
# OTHER RAILROAD CROSSING        141
# RR CROSSING SIGN                71
# NO PASSING                      27
# BICYCLE CROSSING SIGN           17
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64

# %%
new_df['DEVICE_CONDITION'].value_counts()
# Out:
# NO CONTROLS                 345423
# FUNCTIONING PROPERLY        205505
# UNKNOWN                      33526
# OTHER                         4602
# FUNCTIONING IMPROPERLY        2990
# NOT FUNCTIONING               1916
# WORN REFLECTIVE MATERIAL       235
# MISSING                         73
# Name: DEVICE_CONDITION, dtype: int64

# %%
new_df['DATE_POLICE_NOTIFIED'].value_counts()
# Out:
# 10/12/2020 04:00:00 PM    12
# 02/26/2020 08:30:00 AM    12
# 06/30/2018 09:30:00 PM    11
# 02/19/2021 04:00:00 PM    11
# 09/13/2019 05:00:00 PM    11
#                           ..
# 01/08/2017 11:40:00 AM     1
# 04/19/2021 03:52:00 PM     1
# 06/11/2017 06:35:00 PM     1
# 03/25/2018 02:29:00 AM     1
# 03/02/2022 09:40:00 PM     1
# Name: DATE_POLICE_NOTIFIED, Length: 454264, dtype: int64

# %%
new_df['INJURIES_TOTAL'].value_counts()
# Out:
# 0.0     514375
# 1.0      59467
# 2.0      12985
# 3.0       3938
# 4.0       1410
# 5.0        511
# 6.0        206
# 7.0         75
# 8.0         27
# 9.0         16
# 10.0         9
# 15.0         5
# 11.0         5
# 21.0         3
# 12.0         2
# 13.0         2
# 19.0         1
# 16.0         1
# Name: INJURIES_TOTAL, dtype: int64

# %%
new_df['CRASH_DATE'] = pd.to_datetime(new_df['CRASH_DATE'])

# %%
new_df.head(1)
# Out:
#       RD_NO          CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  JF146223 2022-02-16 11:30:00                  15            NO CONTROLS
#
#   DEVICE_CONDITION WEATHER_CONDITION LIGHTING_CONDITION FIRST_CRASH_TYPE  \
# 0      NO CONTROLS             CLEAR           DAYLIGHT     REAR TO REAR
#
#   TRAFFICWAY_TYPE           ALIGNMENT  ... INJURIES_INCAPACITATING  \
# 0     PARKING LOT  STRAIGHT AND LEVEL  ...                     0.0
#
#   INJURIES_NON_INCAPACITATING INJURIES_REPORTED_NOT_EVIDENT  \
# 0                         0.0                           0.0
#
#   INJURIES_NO_INDICATION INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK  \
# 0                    2.0              0.0         11                 4
#
#   CRASH_MONTH   LATITUDE  LONGITUDE
# 0           2  41.909765 -87.743376
#
# [1 rows x 36 columns]

# %%
wont_use = ['SEC_CONTRIBUTORY_CAUSE', 'DATE_POLICE_NOTIFIED', 'INJURIES_FATAL', 'INJURIES_INCAPACITATING',
    'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN',
        'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH']

crashes_clean = new_df.drop(wont_use, axis=1)
crashes_clean.to_csv('crashes_clean')
